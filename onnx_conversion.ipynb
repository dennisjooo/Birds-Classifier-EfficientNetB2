# %% [markdown]
# # Conversion to ONNX
#
# Cool request and which resulted in exploration lol.
# Thanks [Chriamue from Hugging Face](https://huggingface.co/dennisjooo/Birds-Classifier-EfficientNetB2/discussions/1).
#
# Turns out it's not as straight forward because a direct conversion from EfficientNet HF model to a ONNX model isn't supported by Optimum yet.

# %% [markdown]
# ## Imports and all that fun stuff

# %% [markdown]
# ### Installing the things we need
# I used colab for this, there are a couple of things you need to install, first of all, the protobuf-compiler and libprotoc-dev, which are needed for the onnx conversion.

# %%
# Install ONNX in Colab
# !sudo apt-get install protobuf-compiler libprotoc-dev
# !pip -qq install onnx

# %% [markdown]
# Next the colab environment is pre-installed with PyTorch for CUDA, so we need to install the CPU version of PyTorch. We'll also install transformers to download the model from the Hugging Face model hub as well as Optimum for the conversion, specifically the onnxruntime version.

# %%
# Installing the CPU version of torch
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu

# Installing Huggingface's transformers and optimum
# !pip -qq install transformers
# !pip -qq install optimum["onnxruntime"]
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# protobuf-compiler is already the newest version (3.12.4-1ubuntu7.22.04.1).
# The following additional packages will be installed:
#   libprotobuf-dev libprotobuf-lite23
# The following NEW packages will be installed:
#   libprotobuf-dev libprotobuf-lite23 libprotoc-dev
# 0 upgraded, 3 newly installed, 0 to remove and 18 not upgraded.
# Need to get 2,554 kB of archives.
# After this operation, 19.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotobuf-lite23 amd64 3.12.4-1ubuntu7.22.04.1 [209 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotobuf-dev amd64 3.12.4-1ubuntu7.22.04.1 [1,347 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotoc-dev amd64 3.12.4-1ubuntu7.22.04.1 [999 kB]
# Fetched 2,554 kB in 1s (1,844 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libprotobuf-lite23:amd64.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../libprotobuf-lite23_3.12.4-1ubuntu7.22.04.1_amd64.deb ...
# Unpacking libprotobuf-lite23:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../libprotobuf-dev_3.12.4-1ubuntu7.22.04.1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# Selecting previously unselected package libprotoc-dev:amd64.
# Preparing to unpack .../libprotoc-dev_3.12.4-1ubuntu7.22.04.1_amd64.deb ...
# Unpacking libprotoc-dev:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# Setting up libprotobuf-lite23:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# Setting up libprotobuf-dev:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# Setting up libprotoc-dev:amd64 (3.12.4-1ubuntu7.22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 110.5 MB/s eta 0:00:00
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.0.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 53.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 137.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 91.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.0/301.0 kB 6.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 26.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 100.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.5 MB/s eta 0:00:00
#   Building wheel for optimum (pyproject.toml) ... done

# %% [markdown]
# ### Importing the things we need
# Next, just load the things we've installed.

# %%
# Importing modules to load the model and preprocessor from HF
from transformers import EfficientNetForImageClassification, EfficientNetImageProcessor, AutoConfig

# Importing torch goodies
import torch
import torch.nn as nn

# Importing ONNX and HF's ONNX inference
import onnx
import onnxruntime as ort
from optimum.onnxruntime import ORTModelForImageClassification
from optimum.pipelines import pipeline

# Importing stuff to visualise the end result
from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Model conversion

# %% [markdown]
# ### Loading the model
#
# First and foremost, let's load the model from the Hugging Face model hub.

# %%
# Loading in the model from HF
model = EfficientNetForImageClassification.from_pretrained("dennisjooo/Birds-Classifier-EfficientNetB2")

# %% [markdown]
# ### Explicit paddding
#
# Next up, I found that the model architecture is not supported by Optimum, so we need to modify the architecture a bit. The biggest issue is that the padding mode is not supported, i.e. `padding_mode='same'`, thus we'll need to recalculate the padding for each layer that uses it. I used [RedEyed's function from StackOverflow](https://stackoverflow.com/questions/68565147/pytorch-unable-to-export-trained-model-as-onnx).
#
# Additionally, I found that `padding_mode='valid'` needed to be explicitly set to (0, 0).

# %%
# Calculating the padding size (since the HF model contains a lot of Conv2D with 'same' padding)
# Taken from RedEyed's answer in https://stackoverflow.com/questions/68565147/pytorch-unable-to-export-trained-model-as-onnx

def calc_same_padding(kernel_size, stride, input_size):
    if isinstance(kernel_size, tuple):
        kernel_size = kernel_size[0]

    if isinstance(stride, tuple):
        stride = stride[0]

    if isinstance(input_size, tuple):
        input_size = input_size[0]

    pad = ((stride - 1) * input_size - stride + kernel_size) / 2
    return (int(pad), int(pad))

def replace_conv2d_with_same_padding(m: nn.Module, input_size=512):
    if isinstance(m, nn.Conv2d):
        if m.padding == "same":
            m.padding = calc_same_padding(
                kernel_size=m.kernel_size,
                stride=m.stride,
                input_size=input_size
            )

        # I figured out that this somehow made the ONNX converter run, basically it's just a strict no padding
        elif m.padding == 'valid':
            m.padding = (0, 0)

# %%
# Setting the model into evaluation mode
model.eval()

# Applying the stuff made above
model = model.apply(lambda m: replace_conv2d_with_same_padding(m, 224))

# %% [markdown]
# ### Adaptive pooling
# Another issue I found was `avg_pool2d` can be a bastard, so I just replaced it with `AdaptiveAvgPool2d` which is supported by Optimum. Thankfully this should not affect the model's performance since that layer is not trainable.

# %%
# Also found out that avg_pool2d causes error, can be replaced with this AdaptiveAvgPool2d
# It's not "learned" and it also squishes the tensor to the right dimension
model.efficientnet.pooler = nn.AdaptiveAvgPool2d(output_size=1)

# %% [markdown]
# ## Conversion
#
# ### Converting to ONNX
# Huff huff, we're almost there. Now we just need to convert the model to ONNX. I don't  really know what most of the parameters are, especially opset_version is, but I used version 9 since that's what the Torch documentation used.
#
# What I realised was `dynamic_axes` can be used to determine which axes are dynamic, i.e. can change in size, and which are static. I used this to set the batch axis as dynamic, since the batch size can change, and the rest as static.

# %%
# Creating a dir called model to save the onnx version
# %mkdir model

# Exporting the model
torch.onnx.export(model,               # model being run
                  torch.randn(1, 3, 260, 260),   # model input (or a tuple for multiple inputs)
                  "model/birds-classifier-efficientnetb2.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=9,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['pixel_values'],   # the model's input names
                  output_names = ['logits'], # the model's logits names
                  dynamic_axes={'pixel_values' : {0 : 'batch_size'},    # variable length axes
                                'logits' : {0 : 'batch_size'}},
                  training=torch.onnx.TrainingMode.EVAL,
                  )
# Out:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# ### Loading the ONNX model
# Finally, we load the ONNX model and check if it works, which it does! Yay!
#
# We can also check the computational graph of the model to see if it's correct, which I honestly don't know how to read, but it looks cool.

# %%
# Loading the ONNX model
model_o = onnx.load("model/birds-classifier-efficientnetb2.onnx")

# Checking that the model is well formed
onnx.checker.check_model(model_o)

# Printing a human readable representation of the graph
print(onnx.helper.printable_graph(model_o.graph))
# Out:
# graph torch_jit (
#   %pixel_values[FLOAT, batch_sizex3x260x260]
# ) initializers (
#   %efficientnet.encoder.blocks.0.squeeze_excite.reduce.weight[FLOAT, 8x32x1x1]
#   %efficientnet.encoder.blocks.0.squeeze_excite.reduce.bias[FLOAT, 8]
#   %efficientnet.encoder.blocks.0.squeeze_excite.expand.weight[FLOAT, 32x8x1x1]
#   %efficientnet.encoder.blocks.0.squeeze_excite.expand.bias[FLOAT, 32]
#   %efficientnet.encoder.blocks.1.squeeze_excite.reduce.weight[FLOAT, 4x16x1x1]
#   %efficientnet.encoder.blocks.1.squeeze_excite.reduce.bias[FLOAT, 4]
#   %efficientnet.encoder.blocks.1.squeeze_excite.expand.weight[FLOAT, 16x4x1x1]
#   %efficientnet.encoder.blocks.1.squeeze_excite.expand.bias[FLOAT, 16]
#   %efficientnet.encoder.blocks.2.squeeze_excite.reduce.weight[FLOAT, 4x96x1x1]
#   %efficientnet.encoder.blocks.2.squeeze_excite.reduce.bias[FLOAT, 4]
#   %efficientnet.encoder.blocks.2.squeeze_excite.expand.weight[FLOAT, 96x4x1x1]
#   %efficientnet.encoder.blocks.2.squeeze_excite.expand.bias[FLOAT, 96]
#   %efficientnet.encoder.blocks.3.squeeze_excite.reduce.weight[FLOAT, 6x144x1x1]
#   %efficientnet.encoder.blocks.3.squeeze_excite.reduce.bias[FLOAT, 6]
#   %efficientnet.encoder.blocks.3.squeeze_excite.expand.weight[FLOAT, 144x6x1x1]
#   %efficientnet.encoder.blocks.3.squeeze_excite.expand.bias[FLOAT, 144]
#   %efficientnet.encoder.blocks.4.squeeze_excite.reduce.weight[FLOAT, 6x144x1x1]
#   %efficientnet.encoder.blocks.4.squeeze_excite.reduce.bias[FLOAT, 6]
#   %efficientnet.encoder.blocks.4.squeeze_excite.expand.weight[FLOAT, 144x6x1x1]
#   %efficientnet.encoder.blocks.4.squeeze_excite.expand.bias[FLOAT, 144]
#   %efficientnet.encoder.blocks.5.squeeze_excite.reduce.weight[FLOAT, 6x144x1x1]
#   %efficientnet.encoder.blocks.5.squeeze_excite.reduce.bias[FLOAT, 6]
#   %efficientnet.encoder.blocks.5.squeeze_excite.expand.weight[FLOAT, 144x6x1x1]
#   %efficientnet.encoder.blocks.5.squeeze_excite.expand.bias[FLOAT, 144]
#   %efficientnet.encoder.blocks.6.squeeze_excite.reduce.weight[FLOAT, 12x288x1x1]
#   %efficientnet.encoder.blocks.6.squeeze_excite.reduce.bias[FLOAT, 12]
#   %efficientnet.encoder.blocks.6.squeeze_excite.expand.weight[FLOAT, 288x12x1x1]
#   %efficientnet.encoder.blocks.6.squeeze_excite.expand.bias[FLOAT, 288]
#   %efficientnet.encoder.blocks.7.squeeze_excite.reduce.weight[FLOAT, 12x288x1x1]
#   %efficientnet.encoder.blocks.7.squeeze_excite.reduce.bias[FLOAT, 12]
#   %efficientnet.encoder.blocks.7.squeeze_excite.expand.weight[FLOAT, 288x12x1x1]
#   %efficientnet.encoder.blocks.7.squeeze_excite.expand.bias[FLOAT, 288]
#   %efficientnet.encoder.blocks.8.squeeze_excite.reduce.weight[FLOAT, 12x288x1x1]
#   %efficientnet.encoder.blocks.8.squeeze_excite.reduce.bias[FLOAT, 12]
#   %efficientnet.encoder.blocks.8.squeeze_excite.expand.weight[FLOAT, 288x12x1x1]
#   %efficientnet.encoder.blocks.8.squeeze_excite.expand.bias[FLOAT, 288]
#   %efficientnet.encoder.blocks.9.squeeze_excite.reduce.weight[FLOAT, 22x528x1x1]
#   %efficientnet.encoder.blocks.9.squeeze_excite.reduce.bias[FLOAT, 22]
#   %efficientnet.encoder.blocks.9.squeeze_excite.expand.weight[FLOAT, 528x22x1x1]
#   %efficientnet.encoder.blocks.9.squeeze_excite.expand.bias[FLOAT, 528]
#   %efficientnet.encoder.blocks.10.squeeze_excite.reduce.weight[FLOAT, 22x528x1x1]
#   %efficientnet.encoder.blocks.10.squeeze_excite.reduce.bias[FLOAT, 22]
#   %efficientnet.encoder.blocks.10.squeeze_excite.expand.weight[FLOAT, 528x22x1x1]
#   %efficientnet.encoder.blocks.10.squeeze_excite.expand.bias[FLOAT, 528]
#   %efficientnet.encoder.blocks.11.squeeze_excite.reduce.weight[FLOAT, 22x528x1x1]
#   %efficientnet.encoder.blocks.11.squeeze_excite.reduce.bias[FLOAT, 22]
#   %efficientnet.encoder.blocks.11.squeeze_excite.expand.weight[FLOAT, 528x22x1x1]
#   %efficientnet.encoder.blocks.11.squeeze_excite.expand.bias[FLOAT, 528]
#   %efficientnet.encoder.blocks.12.squeeze_excite.reduce.weight[FLOAT, 22x528x1x1]
#   %efficientnet.encoder.blocks.12.squeeze_excite.reduce.bias[FLOAT, 22]
#   %efficientnet.encoder.blocks.12.squeeze_excite.expand.weight[FLOAT, 528x22x1x1]
#   %efficientnet.encoder.blocks.12.squeeze_excite.expand.bias[FLOAT, 528]
#   %efficientnet.encoder.blocks.13.squeeze_excite.reduce.weight[FLOAT, 30x720x1x1]
#   %efficientnet.encoder.blocks.13.squeeze_excite.reduce.bias[FLOAT, 30]
#   %efficientnet.encoder.blocks.13.squeeze_excite.expand.weight[FLOAT, 720x30x1x1]
#   %efficientnet.encoder.blocks.13.squeeze_excite.expand.bias[FLOAT, 720]
#   %efficientnet.encoder.blocks.14.squeeze_excite.reduce.weight[FLOAT, 30x720x1x1]
#   %efficientnet.encoder.blocks.14.squeeze_excite.reduce.bias[FLOAT, 30]
#   %efficientnet.encoder.blocks.14.squeeze_excite.expand.weight[FLOAT, 720x30x1x1]
#   %efficientnet.encoder.blocks.14.squeeze_excite.expand.bias[FLOAT, 720]
#   %efficientnet.encoder.blocks.15.squeeze_excite.reduce.weight[FLOAT, 30x720x1x1]
#   %efficientnet.encoder.blocks.15.squeeze_excite.reduce.bias[FLOAT, 30]
#   %efficientnet.encoder.blocks.15.squeeze_excite.expand.weight[FLOAT, 720x30x1x1]
#   %efficientnet.encoder.blocks.15.squeeze_excite.expand.bias[FLOAT, 720]
#   %efficientnet.encoder.blocks.16.squeeze_excite.reduce.weight[FLOAT, 30x720x1x1]
#   %efficientnet.encoder.blocks.16.squeeze_excite.reduce.bias[FLOAT, 30]
#   %efficientnet.encoder.blocks.16.squeeze_excite.expand.weight[FLOAT, 720x30x1x1]
#   %efficientnet.encoder.blocks.16.squeeze_excite.expand.bias[FLOAT, 720]
#   %efficientnet.encoder.blocks.17.squeeze_excite.reduce.weight[FLOAT, 52x1248x1x1]
#   %efficientnet.encoder.blocks.17.squeeze_excite.reduce.bias[FLOAT, 52]
#   %efficientnet.encoder.blocks.17.squeeze_excite.expand.weight[FLOAT, 1248x52x1x1]
#   %efficientnet.encoder.blocks.17.squeeze_excite.expand.bias[FLOAT, 1248]
#   %efficientnet.encoder.blocks.18.squeeze_excite.reduce.weight[FLOAT, 52x1248x1x1]
#   %efficientnet.encoder.blocks.18.squeeze_excite.reduce.bias[FLOAT, 52]
#   %efficientnet.encoder.blocks.18.squeeze_excite.expand.weight[FLOAT, 1248x52x1x1]
#   %efficientnet.encoder.blocks.18.squeeze_excite.expand.bias[FLOAT, 1248]
#   %efficientnet.encoder.blocks.19.squeeze_excite.reduce.weight[FLOAT, 52x1248x1x1]
#   %efficientnet.encoder.blocks.19.squeeze_excite.reduce.bias[FLOAT, 52]
#   %efficientnet.encoder.blocks.19.squeeze_excite.expand.weight[FLOAT, 1248x52x1x1]
#   %efficientnet.encoder.blocks.19.squeeze_excite.expand.bias[FLOAT, 1248]
#   %efficientnet.encoder.blocks.20.squeeze_excite.reduce.weight[FLOAT, 52x1248x1x1]
#   %efficientnet.encoder.blocks.20.squeeze_excite.reduce.bias[FLOAT, 52]
#   %efficientnet.encoder.blocks.20.squeeze_excite.expand.weight[FLOAT, 1248x52x1x1]
#   %efficientnet.encoder.blocks.20.squeeze_excite.expand.bias[FLOAT, 1248]
#   %efficientnet.encoder.blocks.21.squeeze_excite.reduce.weight[FLOAT, 52x1248x1x1]
#   %efficientnet.encoder.blocks.21.squeeze_excite.reduce.bias[FLOAT, 52]
#   %efficientnet.encoder.blocks.21.squeeze_excite.expand.weight[FLOAT, 1248x52x1x1]
#   %efficientnet.encoder.blocks.21.squeeze_excite.expand.bias[FLOAT, 1248]
#   %efficientnet.encoder.blocks.22.squeeze_excite.reduce.weight[FLOAT, 88x2112x1x1]
#   %efficientnet.encoder.blocks.22.squeeze_excite.reduce.bias[FLOAT, 88]
#   %efficientnet.encoder.blocks.22.squeeze_excite.expand.weight[FLOAT, 2112x88x1x1]
#   %efficientnet.encoder.blocks.22.squeeze_excite.expand.bias[FLOAT, 2112]
#   %classifier.weight[FLOAT, 525x1408]
#   %classifier.bias[FLOAT, 525]
#   %onnx::Conv_934[FLOAT, 32x3x3x3]
#   %onnx::Conv_935[FLOAT, 32]
#   %onnx::Conv_937[FLOAT, 32x1x3x3]
#   %onnx::Conv_938[FLOAT, 32]
#   %onnx::Conv_940[FLOAT, 16x32x1x1]
#   %onnx::Conv_941[FLOAT, 16]
#   %onnx::Conv_943[FLOAT, 16x1x3x3]
#   %onnx::Conv_944[FLOAT, 16]
#   %onnx::Conv_946[FLOAT, 16x16x1x1]
#   %onnx::Conv_947[FLOAT, 16]
#   %onnx::Conv_949[FLOAT, 96x16x1x1]
#   %onnx::Conv_950[FLOAT, 96]
#   %onnx::Conv_952[FLOAT, 96x1x3x3]
#   %onnx::Conv_953[FLOAT, 96]
#   %onnx::Conv_955[FLOAT, 24x96x1x1]
#   %onnx::Conv_956[FLOAT, 24]
#   %onnx::Conv_958[FLOAT, 144x24x1x1]
#   %onnx::Conv_959[FLOAT, 144]
#   %onnx::Conv_961[FLOAT, 144x1x3x3]
#   %onnx::Conv_962[FLOAT, 144]
#   %onnx::Conv_964[FLOAT, 24x144x1x1]
#   %onnx::Conv_965[FLOAT, 24]
#   %onnx::Conv_967[FLOAT, 144x24x1x1]
#   %onnx::Conv_968[FLOAT, 144]
#   %onnx::Conv_970[FLOAT, 144x1x3x3]
#   %onnx::Conv_971[FLOAT, 144]
#   %onnx::Conv_973[FLOAT, 24x144x1x1]
#   %onnx::Conv_974[FLOAT, 24]
#   %onnx::Conv_976[FLOAT, 144x24x1x1]
#   %onnx::Conv_977[FLOAT, 144]
#   %onnx::Conv_979[FLOAT, 144x1x5x5]
#   %onnx::Conv_980[FLOAT, 144]
#   %onnx::Conv_982[FLOAT, 48x144x1x1]
#   %onnx::Conv_983[FLOAT, 48]
#   %onnx::Conv_985[FLOAT, 288x48x1x1]
#   %onnx::Conv_986[FLOAT, 288]
#   %onnx::Conv_988[FLOAT, 288x1x5x5]
#   %onnx::Conv_989[FLOAT, 288]
#   %onnx::Conv_991[FLOAT, 48x288x1x1]
#   %onnx::Conv_992[FLOAT, 48]
#   %onnx::Conv_994[FLOAT, 288x48x1x1]
#   %onnx::Conv_995[FLOAT, 288]
#   %onnx::Conv_997[FLOAT, 288x1x5x5]
#   %onnx::Conv_998[FLOAT, 288]
#   %onnx::Conv_1000[FLOAT, 48x288x1x1]
#   %onnx::Conv_1001[FLOAT, 48]
#   %onnx::Conv_1003[FLOAT, 288x48x1x1]
#   %onnx::Conv_1004[FLOAT, 288]
#   %onnx::Conv_1006[FLOAT, 288x1x3x3]
#   %onnx::Conv_1007[FLOAT, 288]
#   %onnx::Conv_1009[FLOAT, 88x288x1x1]
#   %onnx::Conv_1010[FLOAT, 88]
#   %onnx::Conv_1012[FLOAT, 528x88x1x1]
#   %onnx::Conv_1013[FLOAT, 528]
#   %onnx::Conv_1015[FLOAT, 528x1x3x3]
#   %onnx::Conv_1016[FLOAT, 528]
#   %onnx::Conv_1018[FLOAT, 88x528x1x1]
#   %onnx::Conv_1019[FLOAT, 88]
#   %onnx::Conv_1021[FLOAT, 528x88x1x1]
#   %onnx::Conv_1022[FLOAT, 528]
#   %onnx::Conv_1024[FLOAT, 528x1x3x3]
#   %onnx::Conv_1025[FLOAT, 528]
#   %onnx::Conv_1027[FLOAT, 88x528x1x1]
#   %onnx::Conv_1028[FLOAT, 88]
#   %onnx::Conv_1030[FLOAT, 528x88x1x1]
#   %onnx::Conv_1031[FLOAT, 528]
#   %onnx::Conv_1033[FLOAT, 528x1x3x3]
#   %onnx::Conv_1034[FLOAT, 528]
#   %onnx::Conv_1036[FLOAT, 88x528x1x1]
#   %onnx::Conv_1037[FLOAT, 88]
#   %onnx::Conv_1039[FLOAT, 528x88x1x1]
#   %onnx::Conv_1040[FLOAT, 528]
#   %onnx::Conv_1042[FLOAT, 528x1x5x5]
#   %onnx::Conv_1043[FLOAT, 528]
#   %onnx::Conv_1045[FLOAT, 120x528x1x1]
#   %onnx::Conv_1046[FLOAT, 120]
#   %onnx::Conv_1048[FLOAT, 720x120x1x1]
#   %onnx::Conv_1049[FLOAT, 720]
#   %onnx::Conv_1051[FLOAT, 720x1x5x5]
#   %onnx::Conv_1052[FLOAT, 720]
#   %onnx::Conv_1054[FLOAT, 120x720x1x1]
#   %onnx::Conv_1055[FLOAT, 120]
#   %onnx::Conv_1057[FLOAT, 720x120x1x1]
#   %onnx::Conv_1058[FLOAT, 720]
#   %onnx::Conv_1060[FLOAT, 720x1x5x5]
#   %onnx::Conv_1061[FLOAT, 720]
#   %onnx::Conv_1063[FLOAT, 120x720x1x1]
#   %onnx::Conv_1064[FLOAT, 120]
#   %onnx::Conv_1066[FLOAT, 720x120x1x1]
#   %onnx::Conv_1067[FLOAT, 720]
#   %onnx::Conv_1069[FLOAT, 720x1x5x5]
#   %onnx::Conv_1070[FLOAT, 720]
#   %onnx::Conv_1072[FLOAT, 120x720x1x1]
#   %onnx::Conv_1073[FLOAT, 120]
#   %onnx::Conv_1075[FLOAT, 720x120x1x1]
#   %onnx::Conv_1076[FLOAT, 720]
#   %onnx::Conv_1078[FLOAT, 720x1x5x5]
#   %onnx::Conv_1079[FLOAT, 720]
#   %onnx::Conv_1081[FLOAT, 208x720x1x1]
#   %onnx::Conv_1082[FLOAT, 208]
#   %onnx::Conv_1084[FLOAT, 1248x208x1x1]
#   %onnx::Conv_1085[FLOAT, 1248]
#   %onnx::Conv_1087[FLOAT, 1248x1x5x5]
#   %onnx::Conv_1088[FLOAT, 1248]
#   %onnx::Conv_1090[FLOAT, 208x1248x1x1]
#   %onnx::Conv_1091[FLOAT, 208]
#   %onnx::Conv_1093[FLOAT, 1248x208x1x1]
#   %onnx::Conv_1094[FLOAT, 1248]
#   %onnx::Conv_1096[FLOAT, 1248x1x5x5]
#   %onnx::Conv_1097[FLOAT, 1248]
#   %onnx::Conv_1099[FLOAT, 208x1248x1x1]
#   %onnx::Conv_1100[FLOAT, 208]
#   %onnx::Conv_1102[FLOAT, 1248x208x1x1]
#   %onnx::Conv_1103[FLOAT, 1248]
#   %onnx::Conv_1105[FLOAT, 1248x1x5x5]
#   %onnx::Conv_1106[FLOAT, 1248]
#   %onnx::Conv_1108[FLOAT, 208x1248x1x1]
#   %onnx::Conv_1109[FLOAT, 208]
#   %onnx::Conv_1111[FLOAT, 1248x208x1x1]
#   %onnx::Conv_1112[FLOAT, 1248]
#   %onnx::Conv_1114[FLOAT, 1248x1x5x5]
#   %onnx::Conv_1115[FLOAT, 1248]
#   %onnx::Conv_1117[FLOAT, 208x1248x1x1]
#   %onnx::Conv_1118[FLOAT, 208]
#   %onnx::Conv_1120[FLOAT, 1248x208x1x1]
#   %onnx::Conv_1121[FLOAT, 1248]
#   %onnx::Conv_1123[FLOAT, 1248x1x3x3]
#   %onnx::Conv_1124[FLOAT, 1248]
#   %onnx::Conv_1126[FLOAT, 352x1248x1x1]
#   %onnx::Conv_1127[FLOAT, 352]
#   %onnx::Conv_1129[FLOAT, 2112x352x1x1]
#   %onnx::Conv_1130[FLOAT, 2112]
#   %onnx::Conv_1132[FLOAT, 2112x1x3x3]
#   %onnx::Conv_1133[FLOAT, 2112]
#   %onnx::Conv_1135[FLOAT, 352x2112x1x1]
#   %onnx::Conv_1136[FLOAT, 352]
#   %onnx::Conv_1138[FLOAT, 1408x352x1x1]
#   %onnx::Conv_1139[FLOAT, 1408]
# ) {
#   %/efficientnet/embeddings/padding/Pad_output_0 = Pad[mode = 'constant', pads = [0, 0, 0, 0, 0, 0, 1, 1], value = 0](%pixel_values)
#   %/efficientnet/embeddings/convolution/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [0, 0, 0, 0], strides = [2, 2]](%/efficientnet/embeddings/padding/Pad_output_0, %onnx::Conv_934, %onnx::Conv_935)
#   %/efficientnet/embeddings/activation/Sigmoid_output_0 = Sigmoid(%/efficientnet/embeddings/convolution/Conv_output_0)
#   %/efficientnet/embeddings/activation/Mul_output_0 = Mul(%/efficientnet/embeddings/convolution/Conv_output_0, %/efficientnet/embeddings/activation/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 32, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/embeddings/activation/Mul_output_0, %onnx::Conv_937, %onnx::Conv_938)
#   %/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.0/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.0/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.0/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.0.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.0.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.0/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.0/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.0/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.0/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.0/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.0/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.0/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.0.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.0.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.0/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.0/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.0/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.0/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.0/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.0/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.0/squeeze_excite/Mul_output_0, %onnx::Conv_940, %onnx::Conv_941)
#   %/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 16, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/encoder/blocks.0/projection/project_conv/Conv_output_0, %onnx::Conv_943, %onnx::Conv_944)
#   %/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.1/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.1/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.1/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.1.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.1.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.1/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.1/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.1/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.1/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.1/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.1/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.1/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.1.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.1.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.1/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.1/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.1/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.1/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.1/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.1/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.1/squeeze_excite/Mul_output_0, %onnx::Conv_946, %onnx::Conv_947)
#   %/efficientnet/encoder/blocks.1/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.1/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.0/projection/project_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.2/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.1/projection/Add_output_0, %onnx::Conv_949, %onnx::Conv_950)
#   %/efficientnet/encoder/blocks.2/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.2/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.2/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.2/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.2/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_conv_pad/Pad_output_0 = Pad[mode = 'constant', pads = [0, 0, 0, 0, 0, 0, 1, 1], value = 0](%/efficientnet/encoder/blocks.2/expansion/expand_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 96, kernel_shape = [3, 3], pads = [0, 0, 0, 0], strides = [2, 2]](%/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_conv_pad/Pad_output_0, %onnx::Conv_952, %onnx::Conv_953)
#   %/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.2/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.2/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.2/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.2.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.2.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.2/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.2/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.2/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.2/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.2/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.2/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.2/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.2.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.2.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.2/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.2/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.2/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.2/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.2/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.2/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.2/squeeze_excite/Mul_output_0, %onnx::Conv_955, %onnx::Conv_956)
#   %/efficientnet/encoder/blocks.3/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.2/projection/project_conv/Conv_output_0, %onnx::Conv_958, %onnx::Conv_959)
#   %/efficientnet/encoder/blocks.3/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.3/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.3/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.3/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.3/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 144, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/encoder/blocks.3/expansion/expand_act/Mul_output_0, %onnx::Conv_961, %onnx::Conv_962)
#   %/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.3/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.3/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.3/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.3.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.3.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.3/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.3/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.3/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.3/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.3/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.3/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.3/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.3.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.3.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.3/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.3/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.3/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.3/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.3/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.3/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.3/squeeze_excite/Mul_output_0, %onnx::Conv_964, %onnx::Conv_965)
#   %/efficientnet/encoder/blocks.3/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.3/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.2/projection/project_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.4/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.3/projection/Add_output_0, %onnx::Conv_967, %onnx::Conv_968)
#   %/efficientnet/encoder/blocks.4/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.4/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.4/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.4/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.4/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 144, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/encoder/blocks.4/expansion/expand_act/Mul_output_0, %onnx::Conv_970, %onnx::Conv_971)
#   %/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.4/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.4/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.4/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.4.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.4.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.4/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.4/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.4/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.4/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.4/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.4/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.4/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.4.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.4.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.4/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.4/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.4/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.4/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.4/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.4/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.4/squeeze_excite/Mul_output_0, %onnx::Conv_973, %onnx::Conv_974)
#   %/efficientnet/encoder/blocks.4/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.4/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.3/projection/Add_output_0)
#   %/efficientnet/encoder/blocks.5/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.4/projection/Add_output_0, %onnx::Conv_976, %onnx::Conv_977)
#   %/efficientnet/encoder/blocks.5/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.5/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.5/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.5/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.5/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_conv_pad/Pad_output_0 = Pad[mode = 'constant', pads = [0, 0, 2, 2, 0, 0, 2, 2], value = 0](%/efficientnet/encoder/blocks.5/expansion/expand_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 144, kernel_shape = [5, 5], pads = [0, 0, 0, 0], strides = [2, 2]](%/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_conv_pad/Pad_output_0, %onnx::Conv_979, %onnx::Conv_980)
#   %/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.5/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.5/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.5/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.5.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.5.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.5/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.5/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.5/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.5/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.5/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.5/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.5/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.5.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.5.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.5/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.5/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.5/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.5/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.5/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.5/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.5/squeeze_excite/Mul_output_0, %onnx::Conv_982, %onnx::Conv_983)
#   %/efficientnet/encoder/blocks.6/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.5/projection/project_conv/Conv_output_0, %onnx::Conv_985, %onnx::Conv_986)
#   %/efficientnet/encoder/blocks.6/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.6/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.6/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.6/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.6/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 288, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/efficientnet/encoder/blocks.6/expansion/expand_act/Mul_output_0, %onnx::Conv_988, %onnx::Conv_989)
#   %/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.6/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.6/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.6/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.6.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.6.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.6/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.6/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.6/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.6/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.6/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.6/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.6/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.6.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.6.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.6/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.6/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.6/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.6/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.6/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.6/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.6/squeeze_excite/Mul_output_0, %onnx::Conv_991, %onnx::Conv_992)
#   %/efficientnet/encoder/blocks.6/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.6/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.5/projection/project_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.7/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.6/projection/Add_output_0, %onnx::Conv_994, %onnx::Conv_995)
#   %/efficientnet/encoder/blocks.7/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.7/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.7/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.7/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.7/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 288, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/efficientnet/encoder/blocks.7/expansion/expand_act/Mul_output_0, %onnx::Conv_997, %onnx::Conv_998)
#   %/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.7/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.7/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.7/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.7.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.7.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.7/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.7/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.7/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.7/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.7/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.7/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.7/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.7.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.7.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.7/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.7/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.7/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.7/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.7/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.7/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.7/squeeze_excite/Mul_output_0, %onnx::Conv_1000, %onnx::Conv_1001)
#   %/efficientnet/encoder/blocks.7/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.7/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.6/projection/Add_output_0)
#   %/efficientnet/encoder/blocks.8/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.7/projection/Add_output_0, %onnx::Conv_1003, %onnx::Conv_1004)
#   %/efficientnet/encoder/blocks.8/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.8/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.8/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.8/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.8/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_conv_pad/Pad_output_0 = Pad[mode = 'constant', pads = [0, 0, 1, 1, 0, 0, 1, 1], value = 0](%/efficientnet/encoder/blocks.8/expansion/expand_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 288, kernel_shape = [3, 3], pads = [0, 0, 0, 0], strides = [2, 2]](%/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_conv_pad/Pad_output_0, %onnx::Conv_1006, %onnx::Conv_1007)
#   %/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.8/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.8/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.8/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.8.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.8.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.8/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.8/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.8/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.8/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.8/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.8/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.8/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.8.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.8.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.8/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.8/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.8/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.8/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.8/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.8/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.8/squeeze_excite/Mul_output_0, %onnx::Conv_1009, %onnx::Conv_1010)
#   %/efficientnet/encoder/blocks.9/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.8/projection/project_conv/Conv_output_0, %onnx::Conv_1012, %onnx::Conv_1013)
#   %/efficientnet/encoder/blocks.9/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.9/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.9/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.9/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.9/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 528, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/encoder/blocks.9/expansion/expand_act/Mul_output_0, %onnx::Conv_1015, %onnx::Conv_1016)
#   %/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.9/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.9/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.9/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.9.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.9.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.9/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.9/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.9/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.9/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.9/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.9/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.9/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.9.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.9.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.9/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.9/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.9/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.9/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.9/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.9/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.9/squeeze_excite/Mul_output_0, %onnx::Conv_1018, %onnx::Conv_1019)
#   %/efficientnet/encoder/blocks.9/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.9/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.8/projection/project_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.10/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.9/projection/Add_output_0, %onnx::Conv_1021, %onnx::Conv_1022)
#   %/efficientnet/encoder/blocks.10/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.10/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.10/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.10/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.10/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.10/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 528, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/encoder/blocks.10/expansion/expand_act/Mul_output_0, %onnx::Conv_1024, %onnx::Conv_1025)
#   %/efficientnet/encoder/blocks.10/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.10/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.10/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.10/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.10/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.10/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.10/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.10/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.10/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.10.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.10.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.10/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.10/squeeze_excite/reduce/Conv_output_0)
# ...
#   %/efficientnet/encoder/blocks.18/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.18/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.17/projection/Add_output_0)
#   %/efficientnet/encoder/blocks.19/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.18/projection/Add_output_0, %onnx::Conv_1102, %onnx::Conv_1103)
#   %/efficientnet/encoder/blocks.19/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.19/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.19/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.19/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.19/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1248, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/efficientnet/encoder/blocks.19/expansion/expand_act/Mul_output_0, %onnx::Conv_1105, %onnx::Conv_1106)
#   %/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.19/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.19/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.19/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.19.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.19.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.19/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.19/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.19/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.19/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.19/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.19/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.19/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.19.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.19.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.19/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.19/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.19/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.19/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.19/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.19/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.19/squeeze_excite/Mul_output_0, %onnx::Conv_1108, %onnx::Conv_1109)
#   %/efficientnet/encoder/blocks.19/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.19/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.18/projection/Add_output_0)
#   %/efficientnet/encoder/blocks.20/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.19/projection/Add_output_0, %onnx::Conv_1111, %onnx::Conv_1112)
#   %/efficientnet/encoder/blocks.20/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.20/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.20/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.20/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.20/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1248, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/efficientnet/encoder/blocks.20/expansion/expand_act/Mul_output_0, %onnx::Conv_1114, %onnx::Conv_1115)
#   %/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.20/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.20/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.20/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.20.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.20.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.20/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.20/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.20/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.20/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.20/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.20/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.20/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.20.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.20.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.20/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.20/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.20/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.20/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.20/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.20/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.20/squeeze_excite/Mul_output_0, %onnx::Conv_1117, %onnx::Conv_1118)
#   %/efficientnet/encoder/blocks.20/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.20/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.19/projection/Add_output_0)
#   %/efficientnet/encoder/blocks.21/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.20/projection/Add_output_0, %onnx::Conv_1120, %onnx::Conv_1121)
#   %/efficientnet/encoder/blocks.21/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.21/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.21/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.21/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.21/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1248, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/encoder/blocks.21/expansion/expand_act/Mul_output_0, %onnx::Conv_1123, %onnx::Conv_1124)
#   %/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.21/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.21/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.21/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.21.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.21.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.21/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.21/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.21/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.21/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.21/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.21/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.21/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.21.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.21.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.21/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.21/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.21/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.21/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.21/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.21/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.21/squeeze_excite/Mul_output_0, %onnx::Conv_1126, %onnx::Conv_1127)
#   %/efficientnet/encoder/blocks.22/expansion/expand_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.21/projection/project_conv/Conv_output_0, %onnx::Conv_1129, %onnx::Conv_1130)
#   %/efficientnet/encoder/blocks.22/expansion/expand_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.22/expansion/expand_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.22/expansion/expand_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.22/expansion/expand_conv/Conv_output_0, %/efficientnet/encoder/blocks.22/expansion/expand_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 2112, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/efficientnet/encoder/blocks.22/expansion/expand_act/Mul_output_0, %onnx::Conv_1132, %onnx::Conv_1133)
#   %/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_act/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_conv/Conv_output_0)
#   %/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_act/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_conv/Conv_output_0, %/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_act/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.22/squeeze_excite/squeeze/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_act/Mul_output_0)
#   %/efficientnet/encoder/blocks.22/squeeze_excite/reduce/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.22/squeeze_excite/squeeze/GlobalAveragePool_output_0, %efficientnet.encoder.blocks.22.squeeze_excite.reduce.weight, %efficientnet.encoder.blocks.22.squeeze_excite.reduce.bias)
#   %/efficientnet/encoder/blocks.22/squeeze_excite/act_reduce/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.22/squeeze_excite/reduce/Conv_output_0)
#   %/efficientnet/encoder/blocks.22/squeeze_excite/act_reduce/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.22/squeeze_excite/reduce/Conv_output_0, %/efficientnet/encoder/blocks.22/squeeze_excite/act_reduce/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.22/squeeze_excite/expand/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.22/squeeze_excite/act_reduce/Mul_output_0, %efficientnet.encoder.blocks.22.squeeze_excite.expand.weight, %efficientnet.encoder.blocks.22.squeeze_excite.expand.bias)
#   %/efficientnet/encoder/blocks.22/squeeze_excite/act_expand/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/blocks.22/squeeze_excite/expand/Conv_output_0)
#   %/efficientnet/encoder/blocks.22/squeeze_excite/Mul_output_0 = Mul(%/efficientnet/encoder/blocks.22/depthwise_conv/depthwise_act/Mul_output_0, %/efficientnet/encoder/blocks.22/squeeze_excite/act_expand/Sigmoid_output_0)
#   %/efficientnet/encoder/blocks.22/projection/project_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.22/squeeze_excite/Mul_output_0, %onnx::Conv_1135, %onnx::Conv_1136)
#   %/efficientnet/encoder/blocks.22/projection/Add_output_0 = Add(%/efficientnet/encoder/blocks.22/projection/project_conv/Conv_output_0, %/efficientnet/encoder/blocks.21/projection/project_conv/Conv_output_0)
#   %/efficientnet/encoder/top_conv/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/efficientnet/encoder/blocks.22/projection/Add_output_0, %onnx::Conv_1138, %onnx::Conv_1139)
#   %/efficientnet/encoder/top_activation/Sigmoid_output_0 = Sigmoid(%/efficientnet/encoder/top_conv/Conv_output_0)
#   %/efficientnet/encoder/top_activation/Mul_output_0 = Mul(%/efficientnet/encoder/top_conv/Conv_output_0, %/efficientnet/encoder/top_activation/Sigmoid_output_0)
#   %/efficientnet/pooler/GlobalAveragePool_output_0 = GlobalAveragePool(%/efficientnet/encoder/top_activation/Mul_output_0)
#   %/efficientnet/Shape_output_0 = Shape(%/efficientnet/pooler/GlobalAveragePool_output_0)
#   %/efficientnet/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/efficientnet/Gather_output_0 = Gather[axis = 0](%/efficientnet/Shape_output_0, %/efficientnet/Constant_output_0)
#   %/efficientnet/Shape_1_output_0 = Shape(%/efficientnet/pooler/GlobalAveragePool_output_0)
#   %/efficientnet/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/efficientnet/Gather_1_output_0 = Gather[axis = 0](%/efficientnet/Shape_1_output_0, %/efficientnet/Constant_1_output_0)
#   %/efficientnet/Unsqueeze_output_0 = Unsqueeze[axes = [0]](%/efficientnet/Gather_output_0)
#   %/efficientnet/Unsqueeze_1_output_0 = Unsqueeze[axes = [0]](%/efficientnet/Gather_1_output_0)
#   %/efficientnet/Concat_output_0 = Concat[axis = 0](%/efficientnet/Unsqueeze_output_0, %/efficientnet/Unsqueeze_1_output_0)
#   %/efficientnet/Reshape_output_0 = Reshape(%/efficientnet/pooler/GlobalAveragePool_output_0, %/efficientnet/Concat_output_0)
#   %logits = Gemm[alpha = 1, beta = 1, transB = 1](%/efficientnet/Reshape_output_0, %classifier.weight, %classifier.bias)
#   return %logits
# }

# %% [markdown]
# ## Checking if the thing still work

# %% [markdown]
# ### ORT session
#
# We can now load the model into an ORT session and check if it works. We can also check the input and output names, which are `input_ids` and `logits` respectively. Let's give it a try on a random input.

# %%
# Creating an ORT inference session
ort_session = ort.InferenceSession("model/birds-classifier-efficientnetb2.onnx", providers=['CPUExecutionProvider'])

# Running an input through the model
outputs = ort_session.run(
    None,
    {"pixel_values": np.random.randn(10, 3, 260, 260).astype(np.float32)},
)

# Printing the output
print(outputs[0])
# Out:
# [[ 2.5581005   0.4480939   1.8608063  ...  4.00183     1.6038742
#   10.505807  ]
#  [ 2.7691646   0.6599221   1.9201448  ...  4.2995796   1.7002702
#   10.894267  ]
#  [ 2.718375    0.58007085  2.028774   ...  4.519371    1.9452293
#   11.297108  ]
#  ...
#  [ 2.515278    0.54604226  1.7319913  ...  4.224949    1.379953
#   10.95697   ]
#  [ 2.541707    0.3234174   1.7595174  ...  4.3117146   1.6822777
#   11.202993  ]
#  [ 2.6778543   0.7336247   2.062326   ...  4.3585234   1.7799278
#   10.712921  ]]

# %% [markdown]
# ### HF inference
#
# HuggingFace's modules can also use ONNX models, so let's try that out as well. There are a couple of things we need to do first though, like downloading the model's configuration (which is needed for converting classes to index, etc.) and the image processor.

# %%
# Downloading the config and preprocessor from HF
config = AutoConfig.from_pretrained('dennisjooo/Birds-Classifier-EfficientNetB2')
processor = EfficientNetImageProcessor.from_pretrained("dennisjooo/Birds-Classifier-EfficientNetB2")

# Using the HF ORT modules for inference
model_hf = ORTModelForImageClassification.from_pretrained(model_id='model/',
                                                          config=config)
# Out:
# The ONNX file Birds-Classifier-EfficientNetB2.onnx is not a regular name used in optimum.onnxruntime, the ORTModel might not behave as expected.

# %%
# Loading the image
test_dir = "./test_images/"
images = [Image.open(os.path.join(test_dir, path)) for path in os.listdir(test_dir)]

# %%
# Getting the logits
logits = model_hf(processor(images, return_type='np')['pixel_values'])['logits']

# Converting the logits into labels
labels = [model_hf.config.id2label[i] for i in np.argmax(logits, axis=-1)]

# %%
# Sanity check because I'm going mad
for i, image in enumerate(images):
    plt.imshow(image)
    plt.title(labels[i])
    plt.axis("off")
    plt.show()
